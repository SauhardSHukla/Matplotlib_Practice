# %% [markdown]
# <!-- Matplotlib is used to get the data in Visual form that help to handle the various data in the graphical form using pyplot form matplotlib:-
#
# We use the get the data in the form of the Histogram which hold various data in a visaul form to understand data in better format  -->

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1,2,3,5,6,23,3,24,4,2,100,2,45,24,6,4,3,42,5,3,5]
xt=np.arange(len(x))
plt.hist(x,bins='auto',edgecolor ='black')
# plt.xticks(20)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data
data = np.random.normal(0, 1, 1000)

# Plot histogram
counts, bin_edges, patches = plt.hist(data, bins=10, edgecolor='black')
# print(counts)
# print(bin_edges)
# print(patches)


# Customizing x-ticks
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])  # Calculate bin centers
plt.xticks(bin_centers, labels=[f'{edge:.2f}' for edge in bin_centers], rotation=45)

# Add labels and title
plt.xlabel('Bin Ranges')
plt.ylabel('Frequency')
plt.title('Histogram with Custom X-Ticks')

# Show plot
plt.show()
